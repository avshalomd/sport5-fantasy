# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import requests
from pywebcopy import save_website

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load data

# %%
html_file_path = 'data/raw/2021-06-02.html'
data = pd.read_html(html_file_path)

# %% [markdown]
# # Review data

# %%
next_matches_index = 0
standings_indexes = range(1,7)
goalkeepers_index = 7
defenders_index = 8
midfielders_index = 9
forwards_index = 10

# %%
# data[next_matches_index]

# %%
# data[random.randint(min(standings_indexes), max(standings_indexes))]

# %%
# data[random.randint(goalkeepers_index, forwards_index)]

# %% [markdown]
# # Data reorganize and pre-process

# %%
next_matches_columns_renames = {"תאריך": "date", "שעה": "hour", "קבוצה מארחת": "home_team", "תוצאה": "score", "קבוצה אורחת": "away_team", "סקירה": "review"}
next_matches_df = data[next_matches_index].rename(columns=next_matches_columns_renames)
del next_matches_df['hour']
del next_matches_df['review']
next_matches_df['date'] = pd.to_datetime(next_matches_df['date'], format="%d.%m.%Y")

# %%
# next_matches_df

# %%
standings_columns_renames = {"קבוצה": "team", "מש’": "MP", "נצ’": "W", "תיקו": "D", "הפסד": "L", "יחס": "GF-GA", "נקודות": "Pts"}
groups_standings = []
for index in standings_indexes:
    new_standing_df = data[index].rename(columns=standings_columns_renames)
    new_standing_df['GF'] = new_standing_df['GF-GA'].apply(lambda x: (x.split('-'))[0]).astype('int')
    new_standing_df['GA'] = new_standing_df['GF-GA'].apply(lambda x: (x.split('-'))[1]).astype('int')
    new_standing_df['GD'] = new_standing_df['GF'] - new_standing_df['GA']
    del new_standing_df['GF-GA']
    groups_standings.append(new_standing_df)

# %%
# groups_standings[random.randint(0, len(groups_standings)-1)]

# %%
gaolkeepers_columns_renames = {"שוער": "name", "מחיר": "price", "נק’": "points"}
gaolkeepers_df = data[goalkeepers_index].rename(columns=gaolkeepers_columns_renames)
gaolkeepers_df['position'] = 'GK'
del gaolkeepers_df['Unnamed: 3']

defenders_columns_renames = {"הגנה": "name", "מחיר": "price", "נק’": "points"}
defenders_df = data[defenders_index].rename(columns=defenders_columns_renames)
del defenders_df['Unnamed: 3']
defenders_df['position'] = 'D'

midfielders_columns_renames = {"קישור": "name", "מחיר": "price", "נק’": "points"}
midfielders_df = data[midfielders_index].rename(columns=midfielders_columns_renames)
del midfielders_df['Unnamed: 3']
midfielders_df['position'] = 'M'

forwards_columns_renames = {"התקפה": "name", "מחיר": "price", "נק’": "points"}
forwards_df = data[forwards_index].rename(columns=forwards_columns_renames)
del forwards_df['Unnamed: 3']
forwards_df['position'] = 'FW'

# %%
players_df = pd.concat([gaolkeepers_df, defenders_df, midfielders_df, forwards_df], ignore_index=True)
players_df['team'] = players_df['name'].apply(lambda x: ((x.split('('))[1].split(")"))[0])
players_df['name'] = players_df['name'].apply(lambda x: ((x.split('('))[0])[:-1])
players_df['price'] = players_df['price'].apply(lambda x: (x.split('.'))[0]).astype('int')

# %%
# players_df

# %% [markdown]
# # Generate random* lineup
# *with constraints on formation, budget, maximum players allowed from the same team, minimal player price.

# %%
def get_random_lineup(players_df, formation=[4,3,3], budget=100, budget_delta=1, max_same_team=2, min_player_price=4):
    
    if sum(formation) != 10:
        print("Error: Illegal formation. Formation must sum up to 10 players.")
        return
    if (formation[0] < 3 or formation[0] > 5) or (formation[1] < 3 or formation[1] > 5)  or (formation[2] < 1 or formation[2] > 3): 
        print("Error: Illegal formation. 3 <= Defenders,Midfielders <= 5, 1 <= Forwards <= 3")
        return
    
    players_df = players_df[players_df['price'] >= min_player_price]
    
    used_budegt = 0
    same_team = 0
    while (used_budegt < budget - budget_delta) or (used_budegt > budget) or (same_team > max_same_team):
        lineup_df = pd.concat([players_df[players_df['position'] == 'GK'].sample(),
                               players_df[players_df['position'] == 'D'].sample(formation[0]),
                               players_df[players_df['position'] == 'M'].sample(formation[1]),
                               players_df[players_df['position'] == 'FW'].sample(formation[2])])
        used_budegt = lineup_df['price'].sum()
        same_team = lineup_df['team'].value_counts().max()
    
    print(f'Used budget: {used_budegt}.0M')
    return lineup_df

# %%
# lineup_df = get_random_lineup(players_df)
# lineup_df

# %%
# lineup_df = get_random_lineup(players_df, formation=[3,4,3], budget=100, budget_delta=2, max_same_team=2, min_player_price=5)
# lineup_df

# %% [markdown]
# # Features engineering

# %% [markdown]
# ## Teams features
# 1. Average betting odds
# 2. Average power rankings (pr) - source: The Guardian, FIFA, Reddit and my own.
# 3. Form (points lost in last 6 matches)
# 4. Wighted sum (of all features)

# %%
teams_file_path = 'data/teams.csv'
teams_df = pd.read_csv(teams_file_path, encoding='utf-8')
teams_df['name_e'] = teams_df['name_e'].apply(lambda x: x.replace('\xa0', '')) # clean names

# %%
# teams_df

# %%
power_rank_columns = ["theguardian_pr", "fifa_ranking", "reddit1_pr", "reddit2_pr", "my_pr"]
teams_df['power_rank_avg'] = teams_df[power_rank_columns].mean(axis=1)
max_points = 18
teams_df['form_points_lost'] = max_points - ( 3 * teams_df['form_last6'].str.count('W') +  teams_df['form_last6'].str.count('D'))

teams_df.drop(power_rank_columns, axis='columns', inplace=True)
teams_df.drop('form_last6', axis='columns', inplace=True)

# %%
# teams_df

# %% [markdown]
# ### Normalize features
# * MimMax normalize (to [0,1])

# %%
minimum = teams_df['bets_odds'].min()
maximum = teams_df['bets_odds'].max()
teams_df['bets_odds'] = (teams_df['bets_odds'] - minimum)/(maximum - minimum)

minimum = teams_df['power_rank_avg'].min()
maximum = teams_df['power_rank_avg'].max()
teams_df['power_rank_avg'] = (teams_df['power_rank_avg'] - minimum)/(maximum - minimum)

minimum = teams_df['form_points_lost'].min()
maximum = teams_df['form_points_lost'].max()
teams_df['form_points_lost'] = (teams_df['form_points_lost'] - minimum)/(maximum - minimum)

# %%
teams_df
# Out:
#           name_h           name_e  bets_odds  power_rank_avg  form_points_lost
# 0           צרפת           France   0.000000        0.000000          0.153846
# 1         אנגליה          England   0.000716        0.162162          0.230769
# 2          בלגיה          Belgium   0.003110        0.090090          0.153846
# 3           ספרד            Spain   0.006528        0.207207          0.461538
# 4         גרמניה          Germany   0.006650        0.171171          0.615385
# 5        פורטוגל         Portugal   0.008001        0.162162          0.384615
# 6         איטליה            Italy   0.011643        0.171171          0.000000
# 7          הולנד      Netherlands   0.015511        0.351351          0.384615
# 8          דנמרק          Denmark   0.045775        0.297297          0.384615
# 9        קרואטיה          Croatia   0.060550        0.477477          0.846154
# 10        טורקיה           Turkey   0.097383        0.405405          0.538462
# 11        שווייץ      Switzerland   0.141194        0.432432          0.384615
# 12         פולין           Poland   0.153942        0.567568          1.000000
# 13      אוקראינה          Ukraine   0.166772        0.711712          0.923077
# 14         שבדיה           Sweden   0.174589        0.531532          0.230769
# 15       אוסטריה          Austria   0.218687        0.639640          0.769231
# 16         רוסיה           Russia   0.226217        0.765766          0.846154
# 17         צ`כיה   Czech Republic   0.264994        0.648649          0.615385
# 18        וויילס            Wales   0.317932        0.648649          0.461538
# 19       סקוטלנד         Scotland   0.478749        0.909910          0.923077
# 20       סלובקיה         Slovakia   0.711924        0.918919          0.692308
# 21        פינלנד          Finland   0.823549        0.918919          1.000000
# 22       הונגריה          Hungary   0.870511        0.810811          0.307692
# 23  צפון מקדוניה  North Macedonia   1.000000        1.000000          0.615385

# %% [markdown]
# ### Make features "higher is better" and calculate wighted sum feature

# %%
teams_df['bets_odds'] = 1 - teams_df['bets_odds']
teams_df['power_rank_avg'] = 1 - teams_df['power_rank_avg']
teams_df['form_points_lost'] = 1 - teams_df['form_points_lost']

# %%
w_bets_odds = 0.5
w_power_rank_avg = 0.3
w_form_points_lost = 0.2
w_power = 1.4
teams_df['wighted_sum'] = (w_bets_odds * teams_df['bets_odds']) + (w_power_rank_avg * teams_df['power_rank_avg']) + (w_form_points_lost * teams_df['form_points_lost'])
teams_df['wighted_sum'] = np.power(teams_df['wighted_sum'], w_power)

# %%
teams_df.describe()
# Out:
#        bets_odds  power_rank_avg  form_points_lost  wighted_sum
# count  24.000000       24.000000         24.000000    24.000000
# mean    0.758128        0.500000          0.461538     0.541921
# std     0.306170        0.300420          0.290489     0.288458
# min     0.000000        0.000000          0.000000     0.027573
# 25%     0.721771        0.274775          0.211538     0.390561
# 50%     0.852432        0.495495          0.500000     0.585617
# 75%     0.989267        0.801802          0.634615     0.766842
# max     1.000000        1.000000          1.000000     0.957190

# %%
teams_df.sort_values("wighted_sum", inplace=True)
teams_df.plot(x="name_e", y=["wighted_sum"], kind="bar", figsize=(18,6));
plt.grid();
plt.xticks(rotation=90);
plt.title('Teams Wighted Power Rank (Calculated using form, beting odds, FIFA rank etc)');
plt.xlabel('Team');
plt.ylabel('Wighted Power Rank');

# %% [markdown]
# ## Players features
# 1. Accumulated points
# 2. Team power rank
# 3. Team GF
# 4. Team GA
# 5. Team GD
# 6. Opponent power rank diffenrence
# 7. Opponent GF
# 8. Opponent GA
# 9. Opponent GD
# *more features later

# %% [markdown]
# ### Get Team power ranking, GF, GA

# %%
teams_wights_df = teams_df[['name_h', 'wighted_sum']].set_index('name_h')
players_df['team_pr'] = players_df.apply(lambda row: teams_wights_df.loc[row['team']], axis=1)

# %%
total_standings_df = pd.concat(groups_standings)
total_standings_df = total_standings_df[['team', 'GF', 'GA']].set_index('team')
players_df['team_GF'] = players_df.apply(lambda row: total_standings_df.loc[row['team']].get('GF'), axis=1)
players_df['team_GA'] = players_df.apply(lambda row: total_standings_df.loc[row['team']].get('GA'), axis=1)

# %% [markdown]
# ### Get Opponent power ranking, GF, GA

# %%
opponents1_df = next_matches_df[['home_team', 'away_team']].set_index('home_team')
opponents2_df = next_matches_df[['home_team', 'away_team']].set_index('away_team')
opponents_df = pd.concat([opponents1_df, opponents2_df])
opponents_df['opponent'] = opponents_df.fillna('').sum(axis=1)
opponents_df.drop(columns=['home_team', 'away_team'], inplace=True)
players_df['opponent'] = players_df.apply(lambda row: opponents_df.loc[row['team']], axis=1)

# %%
players_df['opponent_pr'] = players_df.apply(lambda row: teams_wights_df.loc[row['opponent']], axis=1)

# %%
players_df['opponent_GF'] = players_df.apply(lambda row: total_standings_df.loc[row['opponent']].get('GF'), axis=1)
players_df['opponent_GA'] = players_df.apply(lambda row: total_standings_df.loc[row['opponent']].get('GA'), axis=1)

# %%
players_df
# Out:
#                      name  price  points position          team   team_pr  \
# 0              הוגו לוריס     10       0       GK          צרפת  0.957190
# 1             אונאי סימון      9       0       GK          ספרד  0.786374
# 2            טיבו קורטואה      9       0       GK         בלגיה  0.917906
# 3             מנואל נוייר      9       0       GK        גרמניה  0.760331
# 4    ג'אנלואיג'י דונארומה      8       0       GK        איטליה  0.920884
# ..                    ...    ...     ...      ...           ...       ...
# 613       מילאן ריסטובסקי      4       0       FW  צפון מקדוניה  0.027573
# 614            מרקוס פורס      4       0       FW        פינלנד  0.046977
# 615           ריאן כריסטי      4       0       FW       סקוטלנד  0.187972
# 616    ולאטקו סטויאנובסקי      3       0       FW  צפון מקדוניה  0.027573
# 617        קרסטה ולקובסקי      3       0       FW  צפון מקדוניה  0.027573
#
#      team_GF  team_GA opponent  opponent_pr  opponent_GF  opponent_GA
# 0          0        0   גרמניה     0.760331            0            0
# 1          0        0    שבדיה     0.615554            0            0
# 2          0        0    רוסיה     0.366186            0            0
# 3          0        0     צרפת     0.957190            0            0
# 4          0        0   טורקיה     0.633793            0            0
# ..       ...      ...      ...          ...          ...          ...
# 613        0        0  אוסטריה     0.427429            0            0
# 614        0        0    דנמרק     0.745812            0            0
# 615        0        0    צ`כיה     0.432834            0            0
# 616        0        0  אוסטריה     0.427429            0            0
# 617        0        0  אוסטריה     0.427429            0            0
#
# [618 rows x 12 columns]

# %% [markdown]
# ## More players features
# * extracted from statistics of World Cup Qualifiers and Nations League metches (whoscored.com)
# 1. Appearances
# 2. Minuts played
# 3. Goals
# 4. Assists
# 5. Shots per Game (SpG)
# 6. Rating - overall performance score
# 7. Appearances % out of maximum number of appearances
# 8. Minuts played % out of maximum number Minuts played
# 9. Goals % out of all team's goals
# 10. Assists % out of all team's assists
# 11. Goals and Assists (GnA) % out of all team's goals and assists.

# %%
teams_names = teams_df['name_e'].values
teams_stats_df_dict = {}
for team in teams_names:
#     print(team)
    team_file_path = f'data/raw/teams/{team}/r1.html'
    team_data = pd.read_html(team_file_path)
    team_df = (team_data[1])[['Player.1', 'Apps', 'Mins', 'Goals', 'Assists', 'SpG', 'Rating']]
    team_df.rename(columns={"Player.1": "Player"}, inplace=True)
    team_df = team_df.replace('-', 0)
    team_df['Player'] = team_df['Player'].apply(lambda x: (x.split(',')[0])[:-3])
    team_df['Apps'] = team_df['Apps'].apply(lambda x: (x.split('(')[0]))
    teams_stats_df_dict[f'{team}'] = team_df

# %%
teams_stats_df_dict2 = {}
for team in teams_names:
#     print(team)
    team_file_path = f'data/raw/teams/{team}/r11.html'
    team_data = pd.read_html(team_file_path)
    team_df = (team_data[1])[['Player.1', 'Apps', 'Mins', 'Goals', 'Assists', 'SpG', 'Rating']]
    team_df.rename(columns={"Player.1": "Player"}, inplace=True)
    team_df = team_df.replace('-', 0)
    team_df['Player'] = team_df['Player'].apply(lambda x: (x.split(',')[0])[:-3])
    team_df['Apps'] = team_df['Apps'].apply(lambda x: (x.split('(')[0]))
    teams_stats_df_dict2[f'{team}'] = team_df

# %%
convert_dict = {'Player': str,
                'Apps': int,
                'Mins': int,
                'Goals': int,
                'Assists': int,
                'SpG': float,
                'Rating': float}

teams_stats_merged_df_dict = {}
for team in teams_names:
    df = teams_stats_df_dict[team].append(teams_stats_df_dict2[team])
    df = df.astype(convert_dict)
    grouped = df.groupby('Player').agg({'Apps': 'sum',
                                    'Mins': 'sum',
                                    'Goals': 'sum',
                                    'Assists': 'sum',
                                    'SpG': 'mean',
                                    'Rating': 'mean'})
    apps_max = grouped['Apps'].max()
    mins_max = grouped['Mins'].max()
    goals_sum = grouped['Goals'].sum()
    assists_sum = grouped['Assists'].sum()
    grouped['Apps%'] = grouped['Apps'] / apps_max
    grouped['Mins%'] = grouped['Mins'] / mins_max
    grouped['Goals%'] = grouped['Goals'] / goals_sum
    grouped['Assists%'] = grouped['Assists'] / assists_sum
    grouped['GnA%'] = (grouped['Goals'] + grouped['Assists']) / (goals_sum + assists_sum)
    teams_stats_merged_df_dict[team] = grouped

# %%
all_players_stats_df = pd.concat(list(teams_stats_merged_df_dict.values()))

# %%
players_names_df = pd.read_csv('data/players.csv', encoding='utf-8-sig')
players_names_df.drop('team', axis=1, inplace=True)

# %%
players_df.set_index('name', inplace=True)

# %%
all_players_stats_df = all_players_stats_df.merge(players_names_df, left_on=all_players_stats_df.index, right_on='name_e')
all_players_stats_df.rename(columns={'name_h': 'name'},inplace=True)
all_players_stats_df.set_index('name', inplace=True)

# %%
players_df = players_df.merge(all_players_stats_df, left_index=True, right_index=True)

# %%
players_df.to_csv('players_stats.csv', encoding='utf-8-sig')
players_df
# Out:
#                       price  points position          team   team_pr  team_GF  \
# name
# הוגו לוריס               10       0       GK          צרפת  0.957190        0
# אונאי סימון               9       0       GK          ספרד  0.786374        0
# טיבו קורטואה              9       0       GK         בלגיה  0.917906        0
# מנואל נוייר               9       0       GK        גרמניה  0.760331        0
# ג'אנלואיג'י דונארומה      8       0       GK        איטליה  0.920884        0
# ...                     ...     ...      ...           ...       ...      ...
# חליל דרויסוגלו            4       0       FW        טורקיה  0.633793        0
# מרקוס פורס                4       0       FW        פינלנד  0.046977        0
# ריאן כריסטי               4       0       FW       סקוטלנד  0.187972        0
# ולאטקו סטויאנובסקי        3       0       FW  צפון מקדוניה  0.027573        0
# קרסטה ולקובסקי            3       0       FW  צפון מקדוניה  0.027573        0
#
#                       team_GA opponent  opponent_pr  opponent_GF  ...  Goals  \
# name                                                              ...
# הוגו לוריס                  0   גרמניה     0.760331            0  ...      0
# אונאי סימון                 0    שבדיה     0.615554            0  ...      0
# טיבו קורטואה                0    רוסיה     0.366186            0  ...      0
# מנואל נוייר                 0     צרפת     0.957190            0  ...      0
# ג'אנלואיג'י דונארומה        0   טורקיה     0.633793            0  ...      0
# ...                       ...      ...          ...          ...  ...    ...
# חליל דרויסוגלו              0   איטליה     0.920884            0  ...      0
# מרקוס פורס                  0    דנמרק     0.745812            0  ...      0
# ריאן כריסטי                 0    צ`כיה     0.432834            0  ...      2
# ולאטקו סטויאנובסקי          0  אוסטריה     0.427429            0  ...      1
# קרסטה ולקובסקי              0  אוסטריה     0.427429            0  ...      0
#
#                       Assists   SpG  Rating     Apps%     Mins%    Goals%  \
# name
# הוגו לוריס                  0  0.00   6.750  1.000000  1.000000  0.000000
# אונאי סימון                 0  0.00   6.120  0.714286  0.702028  0.000000
# טיבו קורטואה                0  0.00   6.385  0.444444  0.444444  0.000000
# מנואל נוייר                 0  0.00   6.505  0.750000  0.736698  0.000000
# ג'אנלואיג'י דונארומה        0  0.00   6.865  1.000000  1.000000  0.000000
# ...                       ...   ...     ...       ...       ...       ...
# חליל דרויסוגלו              0  0.00   6.030  0.000000  0.005900  0.000000
# מרקוס פורס                  0  0.50   6.040  0.000000  0.079320  0.000000
# ריאן כריסטי                 1  2.15   7.380  0.625000  0.684722  0.166667
# ולאטקו סטויאנובסקי          0  1.00   6.385  0.111111  0.203166  0.058824
# קרסטה ולקובסקי              0  0.50   6.140  0.000000  0.031662  0.000000
#
#                       Assists%      GnA%                name_e
# name
# הוגו לוריס                 0.0  0.000000           Hugo Lloris
# אונאי סימון                0.0  0.000000            Unai Simón
# טיבו קורטואה               0.0  0.000000      Thibaut Courtois
# מנואל נוייר                0.0  0.000000          Manuel Neuer
# ג'אנלואיג'י דונארומה       0.0  0.000000  Gianluigi Donnarumma
# ...                        ...       ...                   ...
# חליל דרויסוגלו             0.0  0.000000         Halil Akbunar
# מרקוס פורס                 0.0  0.000000          Marcus Forss
# ריאן כריסטי                0.1  0.136364         Ryan Christie
# ולאטקו סטויאנובסקי         0.0  0.037037    Vlatko Stojanovski
# קרסטה ולקובסקי             0.0  0.000000        Krste Velkoski
#
# [515 rows x 23 columns]

# %%
players_df.describe()
# Out:
#             price  points     team_pr  team_GF  team_GA  opponent_pr  \
# count  515.000000   515.0  515.000000    515.0    515.0   515.000000
# mean     6.198058     0.0    0.549187      0.0      0.0     0.529169
# std      2.225514     0.0    0.285967      0.0      0.0     0.284884
# min      3.000000     0.0    0.027573      0.0      0.0     0.027573
# 25%      5.000000     0.0    0.366186      0.0      0.0     0.366186
# 50%      6.000000     0.0    0.615554      0.0      0.0     0.555679
# 75%      7.000000     0.0    0.786374      0.0      0.0     0.760331
# max     15.000000     0.0    0.957190      0.0      0.0     0.957190
#
#        opponent_GF  opponent_GA        Apps        Mins       Goals  \
# count        515.0        515.0  515.000000  515.000000  515.000000
# mean           0.0          0.0    3.807767  339.170874    0.601942
# std            0.0          0.0    2.476335  210.628331    1.058041
# min            0.0          0.0    0.000000    1.000000    0.000000
# 25%            0.0          0.0    2.000000  159.500000    0.000000
# 50%            0.0          0.0    4.000000  331.000000    0.000000
# 75%            0.0          0.0    6.000000  501.000000    1.000000
# max            0.0          0.0    9.000000  810.000000    7.000000
#
#           Assists         SpG      Rating       Apps%       Mins%      Goals%  \
# count  515.000000  515.000000  515.000000  515.000000  515.000000  515.000000
# mean     0.427184    0.826505    6.752777    0.463700    0.463173    0.041288
# std      0.793970    0.951198    0.473585    0.299806    0.285841    0.072130
# min      0.000000    0.000000    5.100000    0.000000    0.001389    0.000000
# 25%      0.000000    0.050000    6.442500    0.222222    0.222301    0.000000
# 50%      0.000000    0.550000    6.735000    0.444444    0.444444    0.000000
# 75%      1.000000    1.025000    7.037500    0.714286    0.685218    0.066667
# max      5.000000    6.150000   10.000000    1.000000    1.000000    0.500000
#
#          Assists%        GnA%
# count  515.000000  515.000000
# mean     0.039574    0.040616
# std      0.074644    0.057958
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      0.000000    0.000000
# 75%      0.076923    0.062500
# max      0.500000    0.352941

# %% [markdown]
# ## Example (random) lineup

# %%
lineup_df = get_random_lineup(players_df, formation=[3,4,3], budget=100, budget_delta=1, max_same_team=2, min_player_price=5)
lineup_df
# Out:
# Used budget: 100.0M
#                       price  points position     team   team_pr  team_GF  \
# name
# ג'אנלואיג'י דונארומה      8       0       GK   איטליה  0.920884        0
# דיאן לוברן                7       0        D  קרואטיה  0.555679        0
# אדם לאנג                  5       0        D  הונגריה  0.151662        0
# ברטוש ברשינסקי            7       0        D    פולין  0.436064        0
# קווין דה בריינה          13       0        M    בלגיה  0.917906        0
# פלוריאן נויהאוס           6       0        M   גרמניה  0.760331        0
# ברונו פרננדש             11       0        M  פורטוגל  0.823428        0
# דומניקו ברארדי           10       0        M   איטליה  0.920884        0
# קיליאן אמבפה             15       0       FW     צרפת  0.957190        0
# ז'ואאו פליקס             10       0       FW  פורטוגל  0.823428        0
# מרקוס תוראם               8       0       FW     צרפת  0.957190        0
#
#                       team_GA opponent  opponent_pr  opponent_GF  ...  Goals  \
# name                                                              ...
# ג'אנלואיג'י דונארומה        0   טורקיה     0.633793            0  ...      0
# דיאן לוברן                  0   אנגליה     0.869361            0  ...      1
# אדם לאנג                    0  פורטוגל     0.823428            0  ...      0
# ברטוש ברשינסקי              0  סלובקיה     0.127690            0  ...      0
# קווין דה בריינה             0    רוסיה     0.366186            0  ...      2
# פלוריאן נויהאוס             0     צרפת     0.957190            0  ...      0
# ברונו פרננדש                0  הונגריה     0.151662            0  ...      0
# דומניקו ברארדי              0   טורקיה     0.633793            0  ...      3
# קיליאן אמבפה                0   גרמניה     0.760331            0  ...      2
# ז'ואאו פליקס                0  הונגריה     0.151662            0  ...      2
# מרקוס תוראם                 0   גרמניה     0.760331            0  ...      0
#
#                       Assists   SpG  Rating     Apps%     Mins%    Goals%  \
# name
# ג'אנלואיג'י דונארומה        0  0.00   6.865  1.000000  1.000000  0.000000
# דיאן לוברן                  0  0.45   6.955  0.777778  0.777778  0.083333
# אדם לאנג                    1  0.25   6.510  0.750000  0.783333  0.000000
# ברטוש ברשינסקי              1  0.15   6.650  0.750000  0.702128  0.000000
# קווין דה בריינה             4  2.00   7.630  0.666667  0.633333  0.071429
# פלוריאן נויהאוס             0  0.00   5.985  0.000000  0.066849  0.000000
# ברונו פרננדש                1  2.75   7.270  0.777778  0.741975  0.000000
# דומניקו ברארדי              0  1.65   7.605  0.222222  0.234568  0.230769
# קיליאן אמבפה                1  2.10   6.890  0.555556  0.593827  0.142857
# ז'ואאו פליקס                1  1.70   6.735  0.777778  0.691358  0.117647
# מרקוס תוראם                 1  1.00   6.770  0.111111  0.109877  0.000000
#
#                       Assists%      GnA%                name_e
# name
# ג'אנלואיג'י דונארומה  0.000000  0.000000  Gianluigi Donnarumma
# דיאן לוברן            0.000000  0.050000          Dejan Lovren
# אדם לאנג              0.090909  0.035714             Ádám Lang
# ברטוש ברשינסקי        0.076923  0.038462   Bartosz Bereszynski
# קווין דה בריינה       0.200000  0.125000       Kevin De Bruyne
# פלוריאן נויהאוס       0.000000  0.000000       Florian Neuhaus
# ברונו פרננדש          0.071429  0.032258       Bruno Fernandes
# דומניקו ברארדי        0.000000  0.130435      Domenico Berardi
# קיליאן אמבפה          0.125000  0.136364         Kylian Mbappé
# ז'ואאו פליקס          0.071429  0.096774            João Félix
# מרקוס תוראם           0.125000  0.045455         Marcus Thuram
#
# [11 rows x 23 columns]

# %% [markdown]
# ## Filter players pool

# %%
players_filtered_df = pd.DataFrame(columns=players_df.columns)

# %% [markdown]
# ### filter goalkeepers

# %%
min_minuts = 0.60
players_filtered_df.append(players_df[(players_df['position'] == 'GK') & (players_df['Mins%'] > min_minuts)])
# Out:
#                      price points position     team   team_pr team_GF team_GA  \
# הוגו לוריס              10      0       GK     צרפת  0.957190       0       0
# ג'אנלואיג'י דונארומה     8      0       GK   איטליה  0.920884       0       0
# ג'ורדן פיקפורד           8      0       GK   אנגליה  0.869361       0       0
# דומיניק ליבאקוביץ'       7      0       GK  קרואטיה  0.555679       0       0
# יאן זומר                 7      0       GK   שווייץ  0.634722       0       0
# קספר שמייכל              7      0       GK    דנמרק  0.745812       0       0
# אנטון שונין              6      0       GK    רוסיה  0.366186       0       0
# רובין אולסן              6      0       GK    שבדיה  0.615554       0       0
# תומאש ואצליק             6      0       GK    צ`כיה  0.432834       0       0
# לוקאס הרדצקי             4      0       GK   פינלנד  0.046977       0       0
# דייויד מרשל              3      0       GK  סקוטלנד  0.187972       0       0
#
#                      opponent  opponent_pr opponent_GF  ... Goals Assists  \
# הוגו לוריס             גרמניה     0.760331           0  ...     0       0
# ג'אנלואיג'י דונארומה   טורקיה     0.633793           0  ...     0       0
# ג'ורדן פיקפורד        קרואטיה     0.555679           0  ...     0       0
# דומיניק ליבאקוביץ'     אנגליה     0.869361           0  ...     0       0
# יאן זומר               וויילס     0.437581           0  ...     0       0
# קספר שמייכל            פינלנד     0.046977           0  ...     0       0
# אנטון שונין             בלגיה     0.917906           0  ...     0       0
# רובין אולסן              ספרד     0.786374           0  ...     0       0
# תומאש ואצליק          סקוטלנד     0.187972           0  ...     0       0
# לוקאס הרדצקי            דנמרק     0.745812           0  ...     0       0
# דייויד מרשל             צ`כיה     0.432834           0  ...     0       0
#
#                       SpG Rating  Apps%     Mins%  Goals%  Assists%  GnA%  \
# הוגו לוריס            0.0  6.750  1.000  1.000000     0.0       0.0   0.0
# ג'אנלואיג'י דונארומה  0.0  6.865  1.000  1.000000     0.0       0.0   0.0
# ג'ורדן פיקפורד        0.0  6.350  0.750  0.764873     0.0       0.0   0.0
# דומיניק ליבאקוביץ'    0.0  6.390  1.000  1.000000     0.0       0.0   0.0
# יאן זומר              0.0  6.475  1.000  1.000000     0.0       0.0   0.0
# קספר שמייכל           0.0  6.650  1.000  1.000000     0.0       0.0   0.0
# אנטון שונין           0.0  6.655  0.875  0.886076     0.0       0.0   0.0
# רובין אולסן           0.0  6.390  0.750  0.773639     0.0       0.0   0.0
# תומאש ואצליק          0.0  6.480  1.000  0.930159     0.0       0.0   0.0
# לוקאס הרדצקי          0.2  7.030  0.750  0.764873     0.0       0.0   0.0
# דייויד מרשל           0.0  6.620  0.875  0.875000     0.0       0.0   0.0
#
#                                     name_e
# הוגו לוריס                     Hugo Lloris
# ג'אנלואיג'י דונארומה  Gianluigi Donnarumma
# ג'ורדן פיקפורד             Jordan Pickford
# דומיניק ליבאקוביץ'       Dominik Livakovic
# יאן זומר                       Yann Sommer
# קספר שמייכל              Kasper Schmeichel
# אנטון שונין                   Anton Shunin
# רובין אולסן                    Robin Olsen
# תומאש ואצליק                  Tomás Vaclik
# לוקאס הרדצקי                Lukás Hrádecky
# דייויד מרשל                 David Marshall
#
# [11 rows x 23 columns]

# %%
players_filtered_df
# Out:
# Empty DataFrame
# Columns: [price, points, position, team, team_pr, team_GF, team_GA, opponent, opponent_pr, opponent_GF, opponent_GA, Apps, Mins, Goals, Assists, SpG, Rating, Apps%, Mins%, Goals%, Assists%, GnA%, name_e]
# Index: []
#
# [0 rows x 23 columns]
